# %%
import h5py
import os
import matplotlib.pyplot as plt
# %matplotlib widget
import numpy as np
import random
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score
from keras import layers, models
from keras.utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers.legacy import Adagrad, SGD, Adam
import cv2
import visualkeras
from PIL import ImageFont

# %%
def open_data(path):

    # Path to the folder where HDF5 files are saved
    input_folder = path#

    # Initialize an empty list to store image data
    image_data_list = []
    cloud_map_data_list = []

    # Iterate over files in the folder
    for filename in os.listdir(input_folder):
        # Check if the file is an HDF5 file
        if filename.endswith(".h5"):
            input_path = os.path.join(input_folder, filename)

            with h5py.File(input_path, 'r') as file:
                # Check if 'image' dataset exists in the file
                if 'image' in file:
                    img_data = file['image'][:]
                    cp_data = file['label_map'][:]

                    img_max_val = np.max((np.abs(img_data)))
                    img_data = img_data/40

                    image_data_list.append(img_data)
                    cloud_map_data_list.append(cp_data)
                else:
                    print(f"Dataset 'image' not found in file: {input_path}")

    # Convert the list of image data to a numpy array
    image_data = np.array(image_data_list)
    image_data = np.expand_dims(image_data, axis=-1)

    cloud_map_data = np.array(cloud_map_data_list)

    # Display the shape of the resulting array
    print(f"Shape of the image data array: {image_data.shape}")
    print(f"Shape of the cloud map data array: {cloud_map_data.shape}")

    return image_data, cloud_map_data

def cut_images(image_data, section_size, overlap=0.5):
    cut_frames = []

    for image in image_data:
        # Calculate the number of sections along each dimension
        num_rows = (image.shape[0] - section_size) // int(section_size * (1 - overlap)) + 1
        num_cols = (image.shape[1] - section_size) // int(section_size * (1 - overlap)) + 1

        # Cut the image into sections with 50% overlap
        for i in range(num_rows):
            for j in range(num_cols):
                row_start = i * int(section_size * (1 - overlap))
                row_end = row_start + section_size
                col_start = j * int(section_size * (1 - overlap))
                col_end = col_start + section_size

                # Append the cut section to the list
                cut_frames.append(image[row_start:row_end, col_start:col_end, :])
    
    print(f"Shape of the new data array: {(np.array(cut_frames).shape)}")

    return np.array(cut_frames)

def cut_label(image_data, section_size, overlap=0.5):
    cut_frames = []

    for image in image_data:
        # Calculate the number of sections along each dimension
        num_rows = (image.shape[0] - section_size) // int(section_size * (1 - overlap)) + 1
        num_cols = (image.shape[1] - section_size) // int(section_size * (1 - overlap)) + 1

        # Cut the image into sections with 50% overlap
        for i in range(num_rows):
            for j in range(num_cols):
                row_start = i * int(section_size * (1 - overlap))
                row_end = row_start + section_size
                col_start = j * int(section_size * (1 - overlap))
                col_end = col_start + section_size

                # Append the cut section to the list
                cut_frames.append(image[row_start:row_end, col_start:col_end, :])
    
    print(f"Shape of the new data array: {(np.array(cut_frames).shape)}")

    return np.array(cut_frames)

# %%
image_data, cloud_map_data = open_data('/Users/lukas/Dokumente/Uni/SSI/CNN_data/cloudfirewater/')
# Out:
# Shape of the image data array: (38, 320, 256, 1)
# Shape of the cloud map data array: (38, 320, 256, 4)

# %%
cloud_water_map_data = np.delete(cloud_map_data, 3, axis=-1)
cloud_water_map_data.shape
# Out:
# (38, 320, 256, 3)

# %%
fire_list = [index for index, img in enumerate(num_cloud_map_data) if np.any(img == 2)]
fire_images = image_data[fire_list]
fire_labels = cloud_map_data[fire_list]
indices_list, fire_images.shape, fire_labels.shape
# Out:
# ([3, 4, 5, 13, 14, 17, 18, 19, 21, 23, 25, 33, 34, 39],
#  (14, 320, 256, 1),
#  (14, 320, 256, 3))

# %%
# Define the downsampling factor, for example, let's downsample by a factor of 2
downsampling_factor = 2

# Assuming image_data has the shape (XX, a, b, 1)
num_frames, height, width, channels = image_data.shape

# Initialize an array to store the resized frames
resized_frames = np.zeros((num_frames, height // downsampling_factor, width // downsampling_factor, channels))
resized_masks = np.zeros((num_frames, height // downsampling_factor, width // downsampling_factor, channels))


# Resize each frame and store in the new array
for i in range(num_frames):
    resized_frames[i, :, :, 0] = cv2.resize(image_data[i, :, :, 0], 
                                            (width // downsampling_factor, height // downsampling_factor), 
                                            interpolation=cv2.INTER_AREA)
    resized_masks[i, :, :, 0] = cv2.resize(cloud_map_data[i, :, :, 0], 
                                            (width // downsampling_factor, height // downsampling_factor), 
                                            interpolation=cv2.INTER_AREA)
    resized_masks[i, :, :, 0][resized_masks[i, :, :, 0]>0] = 1

# %%
resized_frames.shape, resized_masks.shape
# Out:
# ((44, 256, 320, 1), (44, 256, 320, 1))

# %%
section_size = 128
cut_frames = cut_images(image_data, section_size=section_size, overlap=0.25)
cut_labels = cut_label(cloud_map_data, section_size=section_size, overlap=0.25)
input_shape=(section_size, section_size, 1)
# Out:
# Shape of the new data array: (228, 128, 128, 1)
# Shape of the new data array: (228, 128, 128, 4)

# %%
section_size = 128
cut_fire_frames = cut_images(fire_images, section_size=section_size, overlap=0.25)
cut_fire_labels = cut_label(fire_labels, section_size=section_size, overlap=0.25)
input_shape=(section_size, section_size, 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/lukas/Documents/GitHub/TUB/Cloud Detection/TUBIN_IR_classifier_model.ipynb Cell 11 line 2
#       <a href='vscode-notebook-cell:/Users/lukas/Documents/GitHub/TUB/Cloud%20Detection/TUBIN_IR_classifier_model.ipynb#X52sZmlsZQ%3D%3D?line=0'>1</a> section_size = 128
# ----> <a href='vscode-notebook-cell:/Users/lukas/Documents/GitHub/TUB/Cloud%20Detection/TUBIN_IR_classifier_model.ipynb#X52sZmlsZQ%3D%3D?line=1'>2</a> cut_fire_frames = cut_images(fire_images, section_size=section_size, overlap=0.25)
#       <a href='vscode-notebook-cell:/Users/lukas/Documents/GitHub/TUB/Cloud%20Detection/TUBIN_IR_classifier_model.ipynb#X52sZmlsZQ%3D%3D?line=2'>3</a> cut_fire_labels = cut_label(fire_labels, section_size=section_size, overlap=0.25)
#       <a href='vscode-notebook-cell:/Users/lukas/Documents/GitHub/TUB/Cloud%20Detection/TUBIN_IR_classifier_model.ipynb#X52sZmlsZQ%3D%3D?line=3'>4</a> input_shape=(section_size, section_size, 1)
#
# NameError: name 'fire_images' is not defined

# %%
section_size = 128
cut_frames = cut_images(resized_frames, section_size=section_size)
cut_labels = cut_images(resized_masks, section_size=section_size)
input_shape=(section_size, section_size, 1)
# Out:
# Shape of the new data array: (528, 128, 128, 1)
# Shape of the new data array: (528, 128, 128, 1)

# %%
cut_labels[0].shape
# Out:
# (128, 128, 3)

# %%
np.argmax(cut_labels[i + i_offset, :, :, :], axis=-1).shape
# Out:
# (128, 128)

# %%
num_samples = 3
i_offset = 5

plt.figure(figsize=(12, 15))

# Plot the images and their corresponding cloud maps
for i in range(num_samples):
    # Plot the first image
    plt.subplot(num_samples, 2, i*2 + 1)
    plt.imshow(cut_frames[i + i_offset, :, :], cmap='magma')
    plt.title(f'Image - Sample {i + 1 + i_offset}')
    plt.colorbar(shrink=0.7)

    combined_map = np.argmax(cut_labels[i + i_offset, :, :, :], axis=-1)

    # Plot the corresponding cloud map
    plt.subplot(num_samples, 2, i*2 + 2)
    plt.imshow(combined_map, cmap='binary_r')
    plt.title(f'Cloud Map - Sample {i + 1 + i_offset}')
    plt.colorbar(shrink=0.7)

plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
image_train, image_test, cloud_train, cloud_test = train_test_split(cut_frames, cut_labels, test_size=0.2, random_state=42)

# %%
fire_image_train, fire_image_test, fire_label_train, fire_label_test = train_test_split(cut_fire_frames, cut_fire_labels, test_size=0.2, random_state=42)

# %%
model = models.Sequential()

# Encoder
model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=input_shape))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))

model.add(layers.UpSampling2D(size=(2, 2)))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))

model.add(layers.UpSampling2D(size=(2, 2)))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))

# Output layer
model.add(layers.Conv2D(1, (1, 1), activation='sigmoid'))

#optimizer = Adam(learning_rate=0.001)
#optimizer = Adagrad(learning_rate=0.001)
optimizer = SGD(learning_rate=0.005)

model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_132 (Conv2D)         (None, 128, 128, 64)      640
#
#  batch_normalization_103 (B  (None, 128, 128, 64)      256
#  atchNormalization)
#
#  conv2d_133 (Conv2D)         (None, 128, 128, 64)      36928
#
#  batch_normalization_104 (B  (None, 128, 128, 64)      256
#  atchNormalization)
#
#  max_pooling2d_24 (MaxPooli  (None, 64, 64, 64)        0
#  ng2D)
#
#  conv2d_134 (Conv2D)         (None, 64, 64, 128)       73856
#
#  batch_normalization_105 (B  (None, 64, 64, 128)       512
#  atchNormalization)
#
#  conv2d_135 (Conv2D)         (None, 64, 64, 128)       147584
#
#  batch_normalization_106 (B  (None, 64, 64, 128)       512
#  atchNormalization)
#
#  max_pooling2d_25 (MaxPooli  (None, 32, 32, 128)       0
#  ng2D)
#
#  conv2d_136 (Conv2D)         (None, 32, 32, 256)       295168
#
#  batch_normalization_107 (B  (None, 32, 32, 256)       1024
#  atchNormalization)
#
#  conv2d_137 (Conv2D)         (None, 32, 32, 256)       590080
#
#  up_sampling2d_24 (UpSampli  (None, 64, 64, 256)       0
#  ng2D)
#
#  batch_normalization_108 (B  (None, 64, 64, 256)       1024
#  atchNormalization)
#
#  conv2d_138 (Conv2D)         (None, 64, 64, 128)       295040
#
#  batch_normalization_109 (B  (None, 64, 64, 128)       512
#  atchNormalization)
#
#  conv2d_139 (Conv2D)         (None, 64, 64, 128)       147584
#
#  up_sampling2d_25 (UpSampli  (None, 128, 128, 128)     0
#  ng2D)
#
#  batch_normalization_110 (B  (None, 128, 128, 128)     512
#  atchNormalization)
#
#  conv2d_140 (Conv2D)         (None, 128, 128, 64)      73792
#
#  batch_normalization_111 (B  (None, 128, 128, 64)      256
#  atchNormalization)
#
#  conv2d_141 (Conv2D)         (None, 128, 128, 64)      36928
#
#  conv2d_142 (Conv2D)         (None, 128, 128, 1)       65
#
# =================================================================
# Total params: 1702529 (6.49 MB)
# Trainable params: 1700097 (6.49 MB)
# Non-trainable params: 2432 (9.50 KB)
# _________________________________________________________________

# %%
# Encoder
inputs = layers.Input(shape=input_shape)
conv1 = layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(inputs)
#batch1 = layers.BatchNormalization()(conv1)
conv2 = layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(conv1)
batch2 = layers.BatchNormalization()(conv2)
pool1 = layers.MaxPooling2D((2, 2))(batch2)

conv3 = layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(pool1)
batch3 = layers.BatchNormalization()(conv3)
conv4 = layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(batch3)
batch4 = layers.BatchNormalization()(conv4)
pool2 = layers.MaxPooling2D((2, 2))(batch4)

conv5 = layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(pool2)
batch5 = layers.BatchNormalization()(conv5)
conv6 = layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(batch5)

# Decoder
up7 = layers.UpSampling2D(size=(2, 2))(conv6)
concat7 = layers.Concatenate()([up7, conv4])
batch7 = layers.BatchNormalization()(concat7)
conv7 = layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(batch7)
batch8 = layers.BatchNormalization()(conv7)
conv8 = layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(batch8)
dropout8 = layers.Dropout(0.1)(conv8)

up9 = layers.UpSampling2D(size=(2, 2))(dropout8)
concat9 = layers.Concatenate()([up9, conv2])
batch9 = layers.BatchNormalization()(concat9)
conv9 = layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(batch9)
batch10 = layers.BatchNormalization()(conv9)
conv10 = layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(batch10)
dropout10 = layers.Dropout(0.2)(conv10)

# Output layer
output = layers.Conv2D(4, (1, 1), activation='softmax')(dropout10)

# Create the model
model = models.Model(inputs=inputs, outputs=output)

# Compile the model
optimizer = SGD(learning_rate=0.05)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 128, 128, 1)]        0         []
#
#  conv2d_11 (Conv2D)          (None, 128, 128, 32)         320       ['input_2[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 128, 128, 32)         9248      ['conv2d_11[0][0]']
#
#  batch_normalization_8 (Bat  (None, 128, 128, 32)         128       ['conv2d_12[0][0]']
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 64, 64, 32)           0         ['batch_normalization_8[0][0]'
#  g2D)                                                               ]
#
#  conv2d_13 (Conv2D)          (None, 64, 64, 64)           18496     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_9 (Bat  (None, 64, 64, 64)           256       ['conv2d_13[0][0]']
#  chNormalization)
#
#  conv2d_14 (Conv2D)          (None, 64, 64, 64)           36928     ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  batch_normalization_10 (Ba  (None, 64, 64, 64)           256       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 32, 32, 64)           0         ['batch_normalization_10[0][0]
#  g2D)                                                               ']
#
#  conv2d_15 (Conv2D)          (None, 32, 32, 128)          73856     ['max_pooling2d_3[0][0]']
#
#  batch_normalization_11 (Ba  (None, 32, 32, 128)          512       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  conv2d_16 (Conv2D)          (None, 32, 32, 128)          147584    ['batch_normalization_11[0][0]
#                                                                     ']
#
#  up_sampling2d_2 (UpSamplin  (None, 64, 64, 128)          0         ['conv2d_16[0][0]']
#  g2D)
#
#  concatenate_2 (Concatenate  (None, 64, 64, 192)          0         ['up_sampling2d_2[0][0]',
#  )                                                                   'conv2d_14[0][0]']
#
#  batch_normalization_12 (Ba  (None, 64, 64, 192)          768       ['concatenate_2[0][0]']
#  tchNormalization)
#
#  conv2d_17 (Conv2D)          (None, 64, 64, 64)           110656    ['batch_normalization_12[0][0]
#                                                                     ']
#
#  batch_normalization_13 (Ba  (None, 64, 64, 64)           256       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  conv2d_18 (Conv2D)          (None, 64, 64, 64)           36928     ['batch_normalization_13[0][0]
#                                                                     ']
#
#  dropout_2 (Dropout)         (None, 64, 64, 64)           0         ['conv2d_18[0][0]']
#
#  up_sampling2d_3 (UpSamplin  (None, 128, 128, 64)         0         ['dropout_2[0][0]']
#  g2D)
#
#  concatenate_3 (Concatenate  (None, 128, 128, 96)         0         ['up_sampling2d_3[0][0]',
#  )                                                                   'conv2d_12[0][0]']
#
#  batch_normalization_14 (Ba  (None, 128, 128, 96)         384       ['concatenate_3[0][0]']
#  tchNormalization)
#
#  conv2d_19 (Conv2D)          (None, 128, 128, 32)         27680     ['batch_normalization_14[0][0]
#                                                                     ']
#
#  batch_normalization_15 (Ba  (None, 128, 128, 32)         128       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  conv2d_20 (Conv2D)          (None, 128, 128, 32)         9248      ['batch_normalization_15[0][0]
#                                                                     ']
#
#  dropout_3 (Dropout)         (None, 128, 128, 32)         0         ['conv2d_20[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 128, 128, 4)          132       ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 473764 (1.81 MB)
# Trainable params: 472420 (1.80 MB)
# Non-trainable params: 1344 (5.25 KB)
# __________________________________________________________________________________________________

# %%
# Encoder
inputs = layers.Input(shape=input_shape)
conv1 = layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(inputs)
batch1 = layers.BatchNormalization()(conv1)
conv2 = layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(batch1)
batch2 = layers.BatchNormalization()(conv2)
pool1 = layers.MaxPooling2D((2, 2))(batch2)

conv3 = layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(pool1)
batch3 = layers.BatchNormalization()(conv3)
conv4 = layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(batch3)
batch4 = layers.BatchNormalization()(conv4)
pool2 = layers.MaxPooling2D((2, 2))(batch4)

conv5 = layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(pool2)
batch41 = layers.BatchNormalization()(conv5)
conv6 = layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(batch41)
batch42 = layers.BatchNormalization()(conv6)
pool3 = layers.MaxPooling2D((2, 2))(batch42)

bottleneck5 = layers.Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(pool3)
batch5 = layers.BatchNormalization()(bottleneck5)
bottleneck6 = layers.Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(batch5)

# Decoder
up7 = layers.UpSampling2D(size=(2, 2))(bottleneck6)
concat7 = layers.Concatenate()([up7, conv6])
batch7 = layers.BatchNormalization()(concat7)
conv7 = layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(batch7)
batch8 = layers.BatchNormalization()(conv7)
conv8 = layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(batch8)
dropout8 = layers.Dropout(0.1)(conv8)

up9 = layers.UpSampling2D(size=(2, 2))(dropout8)
concat9 = layers.Concatenate()([up9, conv4])
batch9 = layers.BatchNormalization()(concat9)
conv9 = layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(batch9)
batch10 = layers.BatchNormalization()(conv9)
conv10 = layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(batch10)
dropout10 = layers.Dropout(0.2)(conv10)

up11 = layers.UpSampling2D(size=(2, 2))(dropout10)
concat11 = layers.Concatenate()([up11, conv2])
batch11 = layers.BatchNormalization()(concat11)
conv11 = layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(batch11)
batch12 = layers.BatchNormalization()(conv11)
conv12 = layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(batch12)
dropout12 = layers.Dropout(0.2)(conv12)

# Output layer
output = layers.Conv2D(1, (1, 1), activation='sigmoid')(dropout12)

# Create the model
model = models.Model(inputs=inputs, outputs=output)

# Compile the model
optimizer = SGD(learning_rate=0.005)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# Model: "model_13"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_14 (InputLayer)       [(None, 128, 128, 1)]        0         []
#
#  conv2d_187 (Conv2D)         (None, 128, 128, 64)         640       ['input_14[0][0]']
#
#  batch_normalization_148 (B  (None, 128, 128, 64)         256       ['conv2d_187[0][0]']
#  atchNormalization)
#
#  conv2d_188 (Conv2D)         (None, 128, 128, 64)         36928     ['batch_normalization_148[0][0
#                                                                     ]']
#
#  batch_normalization_149 (B  (None, 128, 128, 64)         256       ['conv2d_188[0][0]']
#  atchNormalization)
#
#  max_pooling2d_34 (MaxPooli  (None, 64, 64, 64)           0         ['batch_normalization_149[0][0
#  ng2D)                                                              ]']
#
#  conv2d_189 (Conv2D)         (None, 64, 64, 128)          73856     ['max_pooling2d_34[0][0]']
#
#  batch_normalization_150 (B  (None, 64, 64, 128)          512       ['conv2d_189[0][0]']
#  atchNormalization)
#
#  conv2d_190 (Conv2D)         (None, 64, 64, 128)          147584    ['batch_normalization_150[0][0
#                                                                     ]']
#
#  batch_normalization_151 (B  (None, 64, 64, 128)          512       ['conv2d_190[0][0]']
#  atchNormalization)
#
#  max_pooling2d_35 (MaxPooli  (None, 32, 32, 128)          0         ['batch_normalization_151[0][0
#  ng2D)                                                              ]']
#
#  conv2d_191 (Conv2D)         (None, 32, 32, 256)          295168    ['max_pooling2d_35[0][0]']
#
#  batch_normalization_152 (B  (None, 32, 32, 256)          1024      ['conv2d_191[0][0]']
#  atchNormalization)
#
#  conv2d_192 (Conv2D)         (None, 32, 32, 256)          590080    ['batch_normalization_152[0][0
#                                                                     ]']
#
#  batch_normalization_153 (B  (None, 32, 32, 256)          1024      ['conv2d_192[0][0]']
#  atchNormalization)
#
#  max_pooling2d_36 (MaxPooli  (None, 16, 16, 256)          0         ['batch_normalization_153[0][0
#  ng2D)                                                              ]']
#
#  conv2d_193 (Conv2D)         (None, 16, 16, 512)          1180160   ['max_pooling2d_36[0][0]']
#
#  batch_normalization_154 (B  (None, 16, 16, 512)          2048      ['conv2d_193[0][0]']
#  atchNormalization)
#
#  conv2d_194 (Conv2D)         (None, 16, 16, 512)          2359808   ['batch_normalization_154[0][0
#                                                                     ]']
#
#  up_sampling2d_34 (UpSampli  (None, 32, 32, 512)          0         ['conv2d_194[0][0]']
#  ng2D)
#
#  concatenate_26 (Concatenat  (None, 32, 32, 768)          0         ['up_sampling2d_34[0][0]',
#  e)                                                                  'conv2d_192[0][0]']
#
#  batch_normalization_155 (B  (None, 32, 32, 768)          3072      ['concatenate_26[0][0]']
#  atchNormalization)
#
#  conv2d_195 (Conv2D)         (None, 32, 32, 256)          1769728   ['batch_normalization_155[0][0
#                                                                     ]']
#
#  batch_normalization_156 (B  (None, 32, 32, 256)          1024      ['conv2d_195[0][0]']
#  atchNormalization)
#
#  conv2d_196 (Conv2D)         (None, 32, 32, 256)          590080    ['batch_normalization_156[0][0
#                                                                     ]']
#
#  dropout_22 (Dropout)        (None, 32, 32, 256)          0         ['conv2d_196[0][0]']
#
#  up_sampling2d_35 (UpSampli  (None, 64, 64, 256)          0         ['dropout_22[0][0]']
#  ng2D)
#
#  concatenate_27 (Concatenat  (None, 64, 64, 384)          0         ['up_sampling2d_35[0][0]',
#  e)                                                                  'conv2d_190[0][0]']
#
#  batch_normalization_157 (B  (None, 64, 64, 384)          1536      ['concatenate_27[0][0]']
#  atchNormalization)
#
#  conv2d_197 (Conv2D)         (None, 64, 64, 128)          442496    ['batch_normalization_157[0][0
#                                                                     ]']
#
#  batch_normalization_158 (B  (None, 64, 64, 128)          512       ['conv2d_197[0][0]']
#  atchNormalization)
#
#  conv2d_198 (Conv2D)         (None, 64, 64, 128)          147584    ['batch_normalization_158[0][0
#                                                                     ]']
#
#  dropout_23 (Dropout)        (None, 64, 64, 128)          0         ['conv2d_198[0][0]']
#
#  up_sampling2d_36 (UpSampli  (None, 128, 128, 128)        0         ['dropout_23[0][0]']
#  ng2D)
#
#  concatenate_28 (Concatenat  (None, 128, 128, 192)        0         ['up_sampling2d_36[0][0]',
#  e)                                                                  'conv2d_188[0][0]']
#
#  batch_normalization_159 (B  (None, 128, 128, 192)        768       ['concatenate_28[0][0]']
#  atchNormalization)
#
#  conv2d_199 (Conv2D)         (None, 128, 128, 64)         110656    ['batch_normalization_159[0][0
#                                                                     ]']
#
#  batch_normalization_160 (B  (None, 128, 128, 64)         256       ['conv2d_199[0][0]']
#  atchNormalization)
#
#  conv2d_200 (Conv2D)         (None, 128, 128, 64)         36928     ['batch_normalization_160[0][0
#                                                                     ]']
#
#  dropout_24 (Dropout)        (None, 128, 128, 64)         0         ['conv2d_200[0][0]']
#
#  conv2d_201 (Conv2D)         (None, 128, 128, 1)          65        ['dropout_24[0][0]']
#
# ==================================================================================================
# Total params: 7794561 (29.73 MB)
# Trainable params: 7788161 (29.71 MB)
# Non-trainable params: 6400 (25.00 KB)
# __________________________________________________________________________________________________

# %%
image_train.shape
# Out:
# (403, 128, 128, 1)

# %%
datagen = ImageDataGenerator(
    rotation_range=20,      # Randomly rotate images in the range (degrees, 0 to 180)
    width_shift_range=0.3,  # Randomly shift images horizontally (fraction of total width)
    height_shift_range=0.3, # Randomly shift images vertically (fraction of total height)
    zoom_range=0.2,
    horizontal_flip=True,   # Randomly flip images horizontally
    vertical_flip=True,    # Randomly flip images vertically
    fill_mode='reflect'
)

batch_size = 16
steps_per_epoch = len(image_train) // batch_size

# Fit the data generator to the training data (assuming you have a variable named 'train_images')
datagen.fit(image_train)
gen_seed = 42

# Create a generator for both the input images and the ground truth masks
image_generator = datagen.flow(image_train, batch_size=batch_size, seed=gen_seed)
mask_generator = datagen.flow(cloud_train, batch_size=batch_size, seed=gen_seed)

# Combine the generators into one using zip
train_generator = zip(image_generator, mask_generator)

#aug_train_images = datagen.flow(image_train, cloud_train, batch_size=batch_size)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=1e-4)


# Define a ModelCheckpoint callback to save the model at each epoch
checkpoint = ModelCheckpoint('model_epoch_{epoch:02d}.h5', save_best_only=False)

# %%
datagen = ImageDataGenerator(
    rotation_range=45,      # Randomly rotate images in the range (degrees, 0 to 180)
    width_shift_range=0.3,  # Randomly shift images horizontally (fraction of total width)
    height_shift_range=0.3, # Randomly shift images vertically (fraction of total height)
    zoom_range=0.2,
    horizontal_flip=True,   # Randomly flip images horizontally
    vertical_flip=True,    # Randomly flip images vertically
    fill_mode='reflect'
)

# Set the seed for reproducibility
seed = 42
np.random.seed(seed)

# Create a flow generator from the original data
flow_generator = datagen.flow(image_train, batch_size=16, seed=seed)
flow_cloud_generator = datagen.flow(cloud_train, batch_size=16, seed=seed)

# Define the number of augmented samples you want for each original sample
n_augmented_samples = 4  # You can adjust this based on your needs

# Generate augmented samples and store them in new arrays
augmented_data = np.zeros((image_train.shape[0] * n_augmented_samples, image_train.shape[1], image_train.shape[2], image_train.shape[3]))
augmented_cloud_maps = np.zeros((cloud_train.shape[0] * n_augmented_samples, cloud_train.shape[1], cloud_train.shape[2], cloud_train.shape[3]))

for i in range(image_train.shape[0]):
    # Get a single augmented sample at a time
    augmented_samples_batch = next(flow_generator)
    augmented_clouds_batch = next(flow_cloud_generator)

    # Extract a single sample from the batch
    augmented_samples = augmented_samples_batch[0]
    augmented_clouds = augmented_clouds_batch[0]

    # Assign the single augmented sample to the corresponding slices
    augmented_data[i * n_augmented_samples: (i + 1) * n_augmented_samples] = augmented_samples
    augmented_cloud_maps[i * n_augmented_samples: (i + 1) * n_augmented_samples] = augmented_clouds

# %%
def plot_history(history):
    
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    #plt.yticks(np.arange(0.8,1.01,0.01))
    #plt.ylim(0.89,1)
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylim(top=1)
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid()

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylim(bottom=0)
    plt.ylabel('Loss')
    plt.legend()
    plt.grid()

    plt.tight_layout()
    plt.show()

# %%
history = model.fit(image_train, cloud_train, batch_size=batch_size, steps_per_epoch=steps_per_epoch, epochs=200, validation_data=(image_test, cloud_test))
# Out:
# Epoch 1/200
# 11/11 [==============================] - 11s 974ms/step - loss: 0.7961 - accuracy: 0.7166 - val_loss: 0.9733 - val_accuracy: 0.7450
# Epoch 2/200
# 11/11 [==============================] - 10s 977ms/step - loss: 0.5765 - accuracy: 0.7896 - val_loss: 0.8345 - val_accuracy: 0.7783
# Epoch 3/200
# 11/11 [==============================] - 10s 946ms/step - loss: 0.4663 - accuracy: 0.8247 - val_loss: 0.7131 - val_accuracy: 0.7999
# Epoch 4/200
# 11/11 [==============================] - 10s 917ms/step - loss: 0.4321 - accuracy: 0.8383 - val_loss: 0.6094 - val_accuracy: 0.8158
# Epoch 5/200
# 11/11 [==============================] - 10s 910ms/step - loss: 0.4768 - accuracy: 0.8214 - val_loss: 0.5567 - val_accuracy: 0.8360
# Epoch 6/200
# 11/11 [==============================] - 10s 904ms/step - loss: 0.4057 - accuracy: 0.8471 - val_loss: 0.5024 - val_accuracy: 0.8484
# Epoch 7/200
# 11/11 [==============================] - 10s 954ms/step - loss: 0.3294 - accuracy: 0.8806 - val_loss: 0.4917 - val_accuracy: 0.8480
# Epoch 8/200
# 11/11 [==============================] - 11s 966ms/step - loss: 0.3692 - accuracy: 0.8677 - val_loss: 0.4469 - val_accuracy: 0.8539
# Epoch 9/200
# 11/11 [==============================] - 10s 893ms/step - loss: 0.4056 - accuracy: 0.8454 - val_loss: 0.4180 - val_accuracy: 0.8480
# Epoch 10/200
# 11/11 [==============================] - 10s 908ms/step - loss: 0.4139 - accuracy: 0.8338 - val_loss: 0.4311 - val_accuracy: 0.8369
# Epoch 11/200
# 11/11 [==============================] - 10s 906ms/step - loss: 0.3460 - accuracy: 0.8737 - val_loss: 0.4387 - val_accuracy: 0.8495
# Epoch 12/200
# 11/11 [==============================] - 10s 893ms/step - loss: 0.3510 - accuracy: 0.8648 - val_loss: 0.4443 - val_accuracy: 0.8331
# Epoch 13/200
# 11/11 [==============================] - 10s 948ms/step - loss: 0.3362 - accuracy: 0.8678 - val_loss: 0.3545 - val_accuracy: 0.8941
# 11/11 [==============================] - 10s 892ms/step - loss: 0.1271 - accuracy: 0.9548 - val_loss: 0.1241 - val_accuracy: 0.9555
# Epoch 187/200
# 11/11 [==============================] - 10s 912ms/step - loss: 0.1668 - accuracy: 0.9383 - val_loss: 0.1400 - val_accuracy: 0.9497
# Epoch 188/200
# 11/11 [==============================] - 10s 925ms/step - loss: 0.1565 - accuracy: 0.9424 - val_loss: 0.1836 - val_accuracy: 0.9337
# Epoch 189/200
# 11/11 [==============================] - 10s 917ms/step - loss: 0.1692 - accuracy: 0.9396 - val_loss: 0.1448 - val_accuracy: 0.9510
# Epoch 190/200
# 11/11 [==============================] - 10s 896ms/step - loss: 0.1278 - accuracy: 0.9542 - val_loss: 0.1258 - val_accuracy: 0.9548
# Epoch 191/200
# 11/11 [==============================] - 10s 917ms/step - loss: 0.1472 - accuracy: 0.9450 - val_loss: 0.1257 - val_accuracy: 0.9550
# Epoch 192/200
# 11/11 [==============================] - 10s 903ms/step - loss: 0.1350 - accuracy: 0.9497 - val_loss: 0.1223 - val_accuracy: 0.9555
# Epoch 193/200
# 11/11 [==============================] - 10s 958ms/step - loss: 0.1480 - accuracy: 0.9448 - val_loss: 0.1295 - val_accuracy: 0.9548
# Epoch 194/200
# 11/11 [==============================] - 10s 952ms/step - loss: 0.1647 - accuracy: 0.9371 - val_loss: 0.1281 - val_accuracy: 0.9544
# Epoch 195/200
# 11/11 [==============================] - 10s 895ms/step - loss: 0.1870 - accuracy: 0.9329 - val_loss: 0.1604 - val_accuracy: 0.9436
# Epoch 196/200
# 11/11 [==============================] - 10s 900ms/step - loss: 0.1665 - accuracy: 0.9376 - val_loss: 0.1335 - val_accuracy: 0.9531
# Epoch 197/200
# 11/11 [==============================] - 10s 893ms/step - loss: 0.1697 - accuracy: 0.9368 - val_loss: 0.3706 - val_accuracy: 0.8718
# Epoch 198/200
# 11/11 [==============================] - 10s 904ms/step - loss: 0.2080 - accuracy: 0.9288 - val_loss: 0.1678 - val_accuracy: 0.9407
# Epoch 199/200
# 11/11 [==============================] - 10s 887ms/step - loss: 0.1416 - accuracy: 0.9473 - val_loss: 0.1378 - val_accuracy: 0.9514
# Epoch 200/200
# 11/11 [==============================] - 10s 890ms/step - loss: 0.1521 - accuracy: 0.9434 - val_loss: 0.1774 - val_accuracy: 0.9383

# %%
history_train = model.fit(image_train, cloud_train, batch_size=batch_size, steps_per_epoch=steps_per_epoch, epochs=50, validation_data=(image_test, cloud_test))#, callbacks=[reduce_lr])

# Append the values from history to history_main
history.history['loss'].extend(history_train.history['loss'])
history.history['val_loss'].extend(history_train.history['val_loss'])
history.history['accuracy'].extend(history_train.history['accuracy'])
history.history['val_accuracy'].extend(history_train.history['val_accuracy'])
# Out:
# Epoch 1/50
# 11/11 [==============================] - 9s 841ms/step - loss: 0.1426 - accuracy: 0.9465 - val_loss: 0.1402 - val_accuracy: 0.9448
# Epoch 2/50
# 11/11 [==============================] - 9s 826ms/step - loss: 0.1706 - accuracy: 0.9382 - val_loss: 0.1288 - val_accuracy: 0.9537
# Epoch 3/50
# 11/11 [==============================] - 8s 774ms/step - loss: 0.1334 - accuracy: 0.9496 - val_loss: 0.1153 - val_accuracy: 0.9579
# Epoch 4/50
# 11/11 [==============================] - 8s 774ms/step - loss: 0.1269 - accuracy: 0.9545 - val_loss: 0.1317 - val_accuracy: 0.9541
# Epoch 5/50
# 11/11 [==============================] - 9s 776ms/step - loss: 0.1274 - accuracy: 0.9518 - val_loss: 0.1303 - val_accuracy: 0.9538
# Epoch 6/50
# 11/11 [==============================] - 8s 769ms/step - loss: 0.1559 - accuracy: 0.9407 - val_loss: 0.1206 - val_accuracy: 0.9577
# Epoch 7/50
# 11/11 [==============================] - 9s 784ms/step - loss: 0.1349 - accuracy: 0.9486 - val_loss: 0.1179 - val_accuracy: 0.9579
# Epoch 8/50
# 11/11 [==============================] - 8s 775ms/step - loss: 0.1254 - accuracy: 0.9526 - val_loss: 0.1287 - val_accuracy: 0.9543
# Epoch 9/50
# 11/11 [==============================] - 8s 772ms/step - loss: 0.1326 - accuracy: 0.9499 - val_loss: 0.1343 - val_accuracy: 0.9510
# Epoch 10/50
# 11/11 [==============================] - 8s 774ms/step - loss: 0.1217 - accuracy: 0.9541 - val_loss: 0.1329 - val_accuracy: 0.9514
# Epoch 11/50
# 11/11 [==============================] - 9s 771ms/step - loss: 0.1699 - accuracy: 0.9404 - val_loss: 0.2643 - val_accuracy: 0.9025
# Epoch 12/50
# 11/11 [==============================] - 9s 779ms/step - loss: 0.1776 - accuracy: 0.9335 - val_loss: 0.1808 - val_accuracy: 0.9307
# Epoch 13/50
# 11/11 [==============================] - 9s 824ms/step - loss: 0.1717 - accuracy: 0.9353 - val_loss: 0.1490 - val_accuracy: 0.9445
# Epoch 14/50
# 11/11 [==============================] - 9s 822ms/step - loss: 0.1419 - accuracy: 0.9465 - val_loss: 0.1528 - val_accuracy: 0.9431
# Epoch 15/50
# 11/11 [==============================] - 9s 779ms/step - loss: 0.1689 - accuracy: 0.9370 - val_loss: 0.1556 - val_accuracy: 0.9481
# Epoch 16/50
# 11/11 [==============================] - 9s 789ms/step - loss: 0.1421 - accuracy: 0.9457 - val_loss: 0.1463 - val_accuracy: 0.9493
# Epoch 17/50
# 11/11 [==============================] - 9s 777ms/step - loss: 0.1460 - accuracy: 0.9464 - val_loss: 0.1462 - val_accuracy: 0.9487
# Epoch 18/50
# 11/11 [==============================] - 9s 778ms/step - loss: 0.1285 - accuracy: 0.9527 - val_loss: 0.1241 - val_accuracy: 0.9561
# Epoch 19/50
# 11/11 [==============================] - 9s 785ms/step - loss: 0.1309 - accuracy: 0.9529 - val_loss: 0.1201 - val_accuracy: 0.9563
# Epoch 20/50
# 11/11 [==============================] - 9s 783ms/step - loss: 0.1496 - accuracy: 0.9433 - val_loss: 0.1828 - val_accuracy: 0.9297
# Epoch 21/50
# 11/11 [==============================] - 9s 778ms/step - loss: 0.1322 - accuracy: 0.9500 - val_loss: 0.1214 - val_accuracy: 0.9551
# Epoch 22/50
# 11/11 [==============================] - 9s 777ms/step - loss: 0.1400 - accuracy: 0.9466 - val_loss: 0.1450 - val_accuracy: 0.9507
# Epoch 23/50
# 11/11 [==============================] - 9s 777ms/step - loss: 0.1264 - accuracy: 0.9537 - val_loss: 0.1231 - val_accuracy: 0.9541
# Epoch 24/50
# 11/11 [==============================] - 9s 776ms/step - loss: 0.1241 - accuracy: 0.9533 - val_loss: 0.1183 - val_accuracy: 0.9565
# Epoch 25/50
# 11/11 [==============================] - 9s 830ms/step - loss: 0.1238 - accuracy: 0.9544 - val_loss: 0.1184 - val_accuracy: 0.9569
# Epoch 26/50
# 11/11 [==============================] - 8s 820ms/step - loss: 0.1251 - accuracy: 0.9532 - val_loss: 0.1439 - val_accuracy: 0.9474
# Epoch 27/50
# 11/11 [==============================] - 9s 790ms/step - loss: 0.1328 - accuracy: 0.9503 - val_loss: 0.1306 - val_accuracy: 0.9513
# Epoch 28/50
# 11/11 [==============================] - 9s 781ms/step - loss: 0.1149 - accuracy: 0.9561 - val_loss: 0.1370 - val_accuracy: 0.9509
# Epoch 29/50
# 11/11 [==============================] - 9s 777ms/step - loss: 0.1352 - accuracy: 0.9496 - val_loss: 0.1222 - val_accuracy: 0.9555
# Epoch 30/50
# 11/11 [==============================] - 9s 779ms/step - loss: 0.1227 - accuracy: 0.9540 - val_loss: 0.1179 - val_accuracy: 0.9576
# Epoch 31/50
# 11/11 [==============================] - 9s 778ms/step - loss: 0.2019 - accuracy: 0.9321 - val_loss: 0.2116 - val_accuracy: 0.9265
# Epoch 32/50
# 11/11 [==============================] - 9s 780ms/step - loss: 0.1717 - accuracy: 0.9363 - val_loss: 0.1486 - val_accuracy: 0.9486
# Epoch 33/50
# 11/11 [==============================] - 9s 774ms/step - loss: 0.1530 - accuracy: 0.9418 - val_loss: 0.1461 - val_accuracy: 0.9490
# Epoch 34/50
# 11/11 [==============================] - 8s 772ms/step - loss: 0.1513 - accuracy: 0.9429 - val_loss: 0.1217 - val_accuracy: 0.9536
# Epoch 35/50
# 11/11 [==============================] - 8s 775ms/step - loss: 0.1210 - accuracy: 0.9555 - val_loss: 0.1241 - val_accuracy: 0.9554
# Epoch 36/50
# 11/11 [==============================] - 9s 786ms/step - loss: 0.1406 - accuracy: 0.9483 - val_loss: 0.1247 - val_accuracy: 0.9522
# Epoch 37/50
# 11/11 [==============================] - 9s 825ms/step - loss: 0.1171 - accuracy: 0.9547 - val_loss: 0.1148 - val_accuracy: 0.9584
# Epoch 38/50
# 11/11 [==============================] - 9s 827ms/step - loss: 0.1512 - accuracy: 0.9450 - val_loss: 0.1243 - val_accuracy: 0.9536
# Epoch 39/50
# 11/11 [==============================] - 9s 789ms/step - loss: 0.1104 - accuracy: 0.9584 - val_loss: 0.1202 - val_accuracy: 0.9575
# Epoch 40/50
# 11/11 [==============================] - 9s 799ms/step - loss: 0.1456 - accuracy: 0.9462 - val_loss: 0.1871 - val_accuracy: 0.9281
# Epoch 41/50
# 11/11 [==============================] - 8s 769ms/step - loss: 0.1324 - accuracy: 0.9485 - val_loss: 0.1214 - val_accuracy: 0.9562
# Epoch 42/50
# 11/11 [==============================] - 8s 770ms/step - loss: 0.1376 - accuracy: 0.9494 - val_loss: 0.1438 - val_accuracy: 0.9490
# Epoch 43/50
# 11/11 [==============================] - 8s 764ms/step - loss: 0.1317 - accuracy: 0.9508 - val_loss: 0.1232 - val_accuracy: 0.9536
# Epoch 44/50
# 11/11 [==============================] - 8s 766ms/step - loss: 0.1250 - accuracy: 0.9525 - val_loss: 0.1148 - val_accuracy: 0.9576
# Epoch 45/50
# 11/11 [==============================] - 9s 776ms/step - loss: 0.1172 - accuracy: 0.9555 - val_loss: 0.1123 - val_accuracy: 0.9587
# Epoch 46/50
# 11/11 [==============================] - 8s 765ms/step - loss: 0.1892 - accuracy: 0.9315 - val_loss: 0.1747 - val_accuracy: 0.9324
# Epoch 47/50
# 11/11 [==============================] - 9s 777ms/step - loss: 0.1383 - accuracy: 0.9481 - val_loss: 0.1360 - val_accuracy: 0.9487
# Epoch 48/50
# 11/11 [==============================] - 9s 776ms/step - loss: 0.1213 - accuracy: 0.9542 - val_loss: 0.1314 - val_accuracy: 0.9511
# Epoch 49/50
# 11/11 [==============================] - 9s 824ms/step - loss: 0.1152 - accuracy: 0.9566 - val_loss: 0.1159 - val_accuracy: 0.9569
# Epoch 50/50
# 11/11 [==============================] - 8s 819ms/step - loss: 0.1245 - accuracy: 0.9531 - val_loss: 0.1181 - val_accuracy: 0.9581

# %%
history_fire = model.fit(top_diff_cut_frames, top_diff_cut_labels, batch_size=5, epochs=20, validation_data=(image_test, cloud_test), callbacks=[early_stopping])

# Append the values from history to history_main
history.history['loss'].extend(history_fire.history['loss'])
history.history['val_loss'].extend(history_fire.history['val_loss'])
history.history['accuracy'].extend(history_fire.history['accuracy'])
history.history['val_accuracy'].extend(history_fire.history['val_accuracy'])
# Out:
# Epoch 1/20
# 10/10 [==============================] - 12s 1s/step - loss: 0.2880 - accuracy: 0.8164 - val_loss: 0.2196 - val_accuracy: 0.8622
# Epoch 2/20
# 10/10 [==============================] - 11s 1s/step - loss: 0.3027 - accuracy: 0.8050 - val_loss: 0.2154 - val_accuracy: 0.8657
# Epoch 3/20
# 10/10 [==============================] - 11s 1s/step - loss: 0.2880 - accuracy: 0.8127 - val_loss: 0.1849 - val_accuracy: 0.8819
# Epoch 4/20
# 10/10 [==============================] - 11s 1s/step - loss: 0.2933 - accuracy: 0.8097 - val_loss: 0.2293 - val_accuracy: 0.8523
# Epoch 5/20
# 10/10 [==============================] - 11s 1s/step - loss: 0.2895 - accuracy: 0.8096 - val_loss: 0.1984 - val_accuracy: 0.8748
# Epoch 6/20
# 10/10 [==============================] - 11s 1s/step - loss: 0.3052 - accuracy: 0.8009 - val_loss: 0.1923 - val_accuracy: 0.8802
# Epoch 7/20
# 10/10 [==============================] - 11s 1s/step - loss: 0.3094 - accuracy: 0.8043 - val_loss: 0.1945 - val_accuracy: 0.8759
# Epoch 8/20
# 10/10 [==============================] - 11s 1s/step - loss: 0.2995 - accuracy: 0.8034 - val_loss: 0.1510 - val_accuracy: 0.9110
# Epoch 9/20
# 10/10 [==============================] - 11s 1s/step - loss: 0.3143 - accuracy: 0.7980 - val_loss: 0.1951 - val_accuracy: 0.8765
# Epoch 10/20
# 10/10 [==============================] - 11s 1s/step - loss: 0.2990 - accuracy: 0.8000 - val_loss: 0.1468 - val_accuracy: 0.9139
# Epoch 11/20
# 10/10 [==============================] - 11s 1s/step - loss: 0.2848 - accuracy: 0.8149 - val_loss: 0.1588 - val_accuracy: 0.9055
# Epoch 12/20
# 10/10 [==============================] - 12s 1s/step - loss: 0.2641 - accuracy: 0.8291 - val_loss: 0.1438 - val_accuracy: 0.9173
# Epoch 13/20
# 10/10 [==============================] - 11s 1s/step - loss: 0.2776 - accuracy: 0.8163 - val_loss: 0.1831 - val_accuracy: 0.8859
# Epoch 14/20
# 10/10 [==============================] - 11s 1s/step - loss: 0.2750 - accuracy: 0.8196 - val_loss: 0.1471 - val_accuracy: 0.9178
# Epoch 15/20
# 10/10 [==============================] - 11s 1s/step - loss: 0.3338 - accuracy: 0.7922 - val_loss: 0.1623 - val_accuracy: 0.9074
# Epoch 16/20
# 10/10 [==============================] - 11s 1s/step - loss: 0.2710 - accuracy: 0.8226 - val_loss: 0.1776 - val_accuracy: 0.8944
# Epoch 17/20
# 10/10 [==============================] - 11s 1s/step - loss: 0.2823 - accuracy: 0.8191 - val_loss: 0.1557 - val_accuracy: 0.9136
# Epoch 18/20
# 10/10 [==============================] - 11s 1s/step - loss: 0.2804 - accuracy: 0.8211 - val_loss: 0.1736 - val_accuracy: 0.8989
# Epoch 19/20
# 10/10 [==============================] - 11s 1s/step - loss: 0.2752 - accuracy: 0.8201 - val_loss: 0.1553 - val_accuracy: 0.9115
# Epoch 20/20
# 10/10 [==============================] - 11s 1s/step - loss: 0.2590 - accuracy: 0.8302 - val_loss: 0.1423 - val_accuracy: 0.9216

# %%
history_gen = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=10, validation_data=(image_test, cloud_test), callbacks=[early_stopping])

# Append the values from history to history_main
# history.history['loss'].extend(history_gen.history['loss'])
# history.history['val_loss'].extend(history_gen.history['val_loss'])
# history.history['accuracy'].extend(history_gen.history['accuracy'])
# history.history['val_accuracy'].extend(history_gen.history['val_accuracy'])
# Out:
# Epoch 1/10
# 22/22 [==============================] - 57s 3s/step - loss: 0.1845 - accuracy: 0.9428 - val_loss: 0.0989 - val_accuracy: 0.9616
# Epoch 2/10
# 22/22 [==============================] - 55s 3s/step - loss: 0.1869 - accuracy: 0.9408 - val_loss: 0.0995 - val_accuracy: 0.9614
# Epoch 3/10
# 22/22 [==============================] - 55s 3s/step - loss: 0.1802 - accuracy: 0.9406 - val_loss: 0.0974 - val_accuracy: 0.9625
# Epoch 4/10
# 22/22 [==============================] - 55s 3s/step - loss: 0.1741 - accuracy: 0.9408 - val_loss: 0.1019 - val_accuracy: 0.9609
# Epoch 5/10
# 22/22 [==============================] - 55s 3s/step - loss: 0.1632 - accuracy: 0.9452 - val_loss: 0.1040 - val_accuracy: 0.9598
# Epoch 6/10
# 22/22 [==============================] - 55s 3s/step - loss: 0.1755 - accuracy: 0.9413 - val_loss: 0.1121 - val_accuracy: 0.9554
# Epoch 7/10
# 22/22 [==============================] - 55s 3s/step - loss: 0.1521 - accuracy: 0.9487 - val_loss: 0.1083 - val_accuracy: 0.9577
# Epoch 8/10
# 22/22 [==============================] - 55s 3s/step - loss: 0.1691 - accuracy: 0.9428 - val_loss: 0.1124 - val_accuracy: 0.9549
# Epoch 9/10
# 22/22 [==============================] - 55s 3s/step - loss: 0.1713 - accuracy: 0.9439 - val_loss: 0.1070 - val_accuracy: 0.9591
# Epoch 10/10
# 22/22 [==============================] - 55s 3s/step - loss: 0.1595 - accuracy: 0.9437 - val_loss: 0.1102 - val_accuracy: 0.9565

# %%
plot_history(history)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 128, 128, 1)]        0         []
#
#  conv2d_22 (Conv2D)          (None, 128, 128, 64)         640       ['input_3[0][0]']
#
#  batch_normalization_18 (Ba  (None, 128, 128, 64)         256       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  conv2d_23 (Conv2D)          (None, 128, 128, 64)         36928     ['batch_normalization_18[0][0]
#                                                                     ']
#
#  batch_normalization_19 (Ba  (None, 128, 128, 64)         256       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  max_pooling2d_4 (MaxPoolin  (None, 64, 64, 64)           0         ['batch_normalization_19[0][0]
#  g2D)                                                               ']
#
#  conv2d_24 (Conv2D)          (None, 64, 64, 128)          73856     ['max_pooling2d_4[0][0]']
#
#  batch_normalization_20 (Ba  (None, 64, 64, 128)          512       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  conv2d_25 (Conv2D)          (None, 64, 64, 128)          147584    ['batch_normalization_20[0][0]
#                                                                     ']
#
#  batch_normalization_21 (Ba  (None, 64, 64, 128)          512       ['conv2d_25[0][0]']
#  tchNormalization)
#
#  max_pooling2d_5 (MaxPoolin  (None, 32, 32, 128)          0         ['batch_normalization_21[0][0]
#  g2D)                                                               ']
#
#  conv2d_26 (Conv2D)          (None, 32, 32, 128)          147584    ['max_pooling2d_5[0][0]']
#
#  batch_normalization_22 (Ba  (None, 32, 32, 128)          512       ['conv2d_26[0][0]']
#  tchNormalization)
#
#  conv2d_27 (Conv2D)          (None, 32, 32, 128)          147584    ['batch_normalization_22[0][0]
#                                                                     ']
#
#  up_sampling2d_4 (UpSamplin  (None, 64, 64, 128)          0         ['conv2d_27[0][0]']
#  g2D)
#
#  concatenate_4 (Concatenate  (None, 64, 64, 256)          0         ['up_sampling2d_4[0][0]',
#  )                                                                   'conv2d_25[0][0]']
#
#  batch_normalization_23 (Ba  (None, 64, 64, 256)          1024      ['concatenate_4[0][0]']
#  tchNormalization)
#
#  conv2d_28 (Conv2D)          (None, 64, 64, 64)           147520    ['batch_normalization_23[0][0]
#                                                                     ']
#
#  batch_normalization_24 (Ba  (None, 64, 64, 64)           256       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  conv2d_29 (Conv2D)          (None, 64, 64, 128)          73856     ['batch_normalization_24[0][0]
#                                                                     ']
#
#  dropout_4 (Dropout)         (None, 64, 64, 128)          0         ['conv2d_29[0][0]']
#
#  up_sampling2d_5 (UpSamplin  (None, 128, 128, 128)        0         ['dropout_4[0][0]']
#  g2D)
#
#  concatenate_5 (Concatenate  (None, 128, 128, 192)        0         ['up_sampling2d_5[0][0]',
#  )                                                                   'conv2d_23[0][0]']
#
#  batch_normalization_25 (Ba  (None, 128, 128, 192)        768       ['concatenate_5[0][0]']
#  tchNormalization)
#
#  conv2d_30 (Conv2D)          (None, 128, 128, 64)         110656    ['batch_normalization_25[0][0]
#                                                                     ']
#
#  batch_normalization_26 (Ba  (None, 128, 128, 64)         256       ['conv2d_30[0][0]']
#  tchNormalization)
#
#  conv2d_31 (Conv2D)          (None, 128, 128, 64)         36928     ['batch_normalization_26[0][0]
#                                                                     ']
#
#  dropout_5 (Dropout)         (None, 128, 128, 64)         0         ['conv2d_31[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 128, 128, 4)          260       ['dropout_5[0][0]']
#
# ==================================================================================================
# Total params: 927748 (3.54 MB)
# Trainable params: 925572 (3.53 MB)
# Non-trainable params: 2176 (8.50 KB)
# __________________________________________________________________________________________________

# %%
#label = np.argmax(cloud_train, axis=-1)
#data = image_train

label = np.argmax(cloud_test, axis=-1)
data = image_test

# Predict on test data
predictions = model.predict(data)

diff = np.zeros(predictions.shape)

diff = np.argmax(predictions, axis=-1) - label
# prediction_threshold = 0.5

# predictions[predictions < prediction_threshold] = 0
# predictions[predictions >= prediction_threshold] = 1
# Out:
# 2/2 [==============================] - 3s 698ms/step

# %%
#label = np.argmax(cloud_test, axis=-1)
#data = image_test



num_samples = 6

rand_offset = random.randint(0, data.shape[0]-num_samples-1)
#rand_offset = 15
print(rand_offset, data.shape[0])

# Plot a few samples  # You can change this number based on your preference

plt.figure(figsize=(12, 8))

for i in range(num_samples):
    # Original image (input)
    plt.subplot(4, num_samples, i + 1)
    plt.imshow(data[i + rand_offset, :, :], cmap='magma', vmin=-1, vmax=1)
    plt.title('Test Image ' + str(i + rand_offset), fontsize=8)
    plt.axis('off')

    # Predicted mask (output)
    plt.subplot(4, num_samples, i + 1 + num_samples)
    plt.imshow(np.argmax(predictions[i + rand_offset, :, :, :], axis=-1), cmap='viridis_r', vmin=-.5, vmax=2.5)
    plt.title('Predicted Cloud Mask ' + str(i + rand_offset), fontsize=8)
    plt.axis('off')

    # True mask
    plt.subplot(4, num_samples, i + 1 + 2 * num_samples)
    plt.imshow(label[i + rand_offset, :, :], cmap='viridis_r', vmin=-.5, vmax=2.5)
    plt.title('Ground Truth Mask ' + str(i + rand_offset), fontsize=8)
    plt.axis('off')



    # diff[i + rand_offset, :, :, 0] = predictions[i + rand_offset, :, :, 0]-label[i + rand_offset, :, :, 0]

    # Diff mask
    plt.subplot(4, num_samples, i + 1 + 3 * num_samples)
    plt.imshow(diff[i + rand_offset, :, :], cmap='RdYlGn', vmin=-1., vmax=1.) #RdBu''
    plt.title('Masks Diffs ' + str(i + rand_offset), fontsize=8)
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 32 46
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
top_threshold = 50
top_diff_index = np.argsort(np.array([abs(i.mean())+i.std() for i in diff]))[::-1][:top_threshold]
#top_diff_index = np.argsort(np.array([abs(i.mean()) for i in diff if i.mean() != 0]))[::-1][-top_threshold:]
#top_diff_index = np.argsort(np.array([i.mean() for i in diff]))[::-1][-top_threshold:]
top_diff_cut_frames = image_train[top_diff_index]
top_diff_cut_labels = cloud_train[top_diff_index]

# %%
top_diff_index
# Out:
# array([196, 291, 132, 359, 214, 268, 248, 191,  16, 349, 348, 363, 322,
#        109, 176, 300, 232, 184, 133,   9, 256, 356, 141, 199, 238,  70,
#        340, 276, 329,  37,  22,  95, 264, 134, 251,  91, 119,  93, 222,
#         19, 254, 213, 296, 178,  56,  86, 234, 353,   0, 198])

# %%
single_frames = cut_frames[3:5]
prediction_single_frame = model.predict(single_frames)
# Out:
# 1/1 [==============================] - 0s 105ms/step

# %%
plt.figure(figsize=(10, 8))

plt.subplot(1, 2, 1)
plt.imshow(np.argmax(prediction_single_frame[0, :, :, :], axis=-1), cmap='jet', vmin=0.0, vmax=3)
plt.title('Predicted Cloud Mask ' + str(14), fontsize=8)
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(cut_frames[3], cmap='magma', vmin=-1, vmax=1)
plt.title('Predicted Cloud Mask ' + str(14), fontsize=8)
plt.axis('off')
# Out:
# (-0.5, 127.5, 127.5, -0.5)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
model.save('best_IR_img2classmap_64.keras')

# %%
model = models.load_model('best_IR_img2classmap_64.keras')
